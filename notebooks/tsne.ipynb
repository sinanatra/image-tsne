# %% [markdown]
# # Image t-SNE

# %% [markdown]
# This notebook loads a folder of images and builds a t-SNE visualisation around them.

# %% [markdown]
# ### Parse all images in custom folder, saves their color and path into the data array

# %%
import matplotlib.pyplot as plt
import cv2
import os
import random
import numpy as np
from PIL import Image
from sklearn.feature_extraction import image
from skimage import io
from sklearn.manifold import TSNE

data = []
folder = '../assets/img-apple-64/'

for filename in os.listdir(folder):
    image = cv2.imread(os.path.join(folder,filename))
    if image is not None:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        image = cv2.resize(image, (45,45))
        image = image.flatten()
        data.append([image, folder + filename])

# %%
features, images  = zip(*data)

# %% [markdown]
# ### Training part

# %% [markdown]
# imagesinstantiate a PCA object, which we will then fit our data to, choosing to keep the top 300 principal components. This may take a few minutes.

# %%
from sklearn.decomposition import PCA

features = np.array(features)
pca = PCA(n_components=300)
pca.fit(features)
pca_features = pca.transform(features)

# %%
num_images_to_plot = len(images)

if len(images) > num_images_to_plot:
    sort_order = sorted(random.sample(range(len(images)), num_images_to_plot))
    images = [images[i] for i in sort_order]
    pca_features = [pca_features[i] for i in sort_order]

# %%
X = np.array(pca_features)
tsne = TSNE(n_components=2, learning_rate=150, perplexity=30, angle=0.2, verbose=2).fit_transform(X)
# Out:
# /Users/giacomonanni/opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3184 samples in 0.002s...
# [t-SNE] Computed neighbors for 3184 samples in 0.266s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3184
# [t-SNE] Computed conditional probabilities for sample 2000 / 3184
# [t-SNE] Computed conditional probabilities for sample 3000 / 3184
# [t-SNE] Computed conditional probabilities for sample 3184 / 3184
# [t-SNE] Mean sigma: 802.794336
# [t-SNE] Computed conditional probabilities in 0.097s
# [t-SNE] Iteration 50: error = 78.7840881, gradient norm = 0.0891342 (50 iterations in 1.014s)
# [t-SNE] Iteration 100: error = 76.9752045, gradient norm = 0.0851306 (50 iterations in 0.764s)
# [t-SNE] Iteration 150: error = 76.9087219, gradient norm = 0.0705917 (50 iterations in 0.919s)
# [t-SNE] Iteration 200: error = 77.0366592, gradient norm = 0.0937457 (50 iterations in 0.857s)
# [t-SNE] Iteration 250: error = 76.9246292, gradient norm = 0.0781702 (50 iterations in 0.850s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.924629
# [t-SNE] Iteration 300: error = 1.8414776, gradient norm = 0.0012603 (50 iterations in 0.694s)
# [t-SNE] Iteration 350: error = 1.5189894, gradient norm = 0.0005056 (50 iterations in 0.646s)
# [t-SNE] Iteration 400: error = 1.3923513, gradient norm = 0.0002851 (50 iterations in 0.653s)
# [t-SNE] Iteration 450: error = 1.3295168, gradient norm = 0.0001857 (50 iterations in 0.649s)
# [t-SNE] Iteration 500: error = 1.2935677, gradient norm = 0.0001351 (50 iterations in 0.658s)
# [t-SNE] Iteration 550: error = 1.2708247, gradient norm = 0.0001030 (50 iterations in 0.646s)
# [t-SNE] Iteration 600: error = 1.2559140, gradient norm = 0.0000822 (50 iterations in 0.657s)
# [t-SNE] Iteration 650: error = 1.2452617, gradient norm = 0.0000679 (50 iterations in 0.651s)
# [t-SNE] Iteration 700: error = 1.2377925, gradient norm = 0.0000567 (50 iterations in 0.657s)
# [t-SNE] Iteration 750: error = 1.2320845, gradient norm = 0.0000486 (50 iterations in 0.674s)
# [t-SNE] Iteration 800: error = 1.2277139, gradient norm = 0.0000428 (50 iterations in 0.771s)
# [t-SNE] Iteration 850: error = 1.2243054, gradient norm = 0.0000369 (50 iterations in 0.671s)
# [t-SNE] Iteration 900: error = 1.2216005, gradient norm = 0.0000327 (50 iterations in 0.668s)
# [t-SNE] Iteration 950: error = 1.2192733, gradient norm = 0.0000314 (50 iterations in 0.688s)
# [t-SNE] Iteration 1000: error = 1.2173989, gradient norm = 0.0000281 (50 iterations in 0.656s)
# [t-SNE] KL divergence after 1000 iterations: 1.217399

# %% [markdown]
# Internally, t-SNE uses an iterative approach, making small (or sometimes large) adjustments to the points. By default, t-SNE will go a maximum of 1000 iterations, but in practice, it often terminates early because it has found a locally optimal (good enough) embedding.
#
# The variable tsne contains an array of unnormalized 2d points, corresponding to the embedding. In the next cell, we normalize the embedding so that lies entirely in the range (0,1).

# %%
tx, ty = tsne[:,0], tsne[:,1]
tx = (tx-np.min(tx)) / (np.max(tx) - np.min(tx))
ty = (ty-np.min(ty)) / (np.max(ty) - np.min(ty))

# %% [markdown]
# ### Plots the clusters

# %%
import matplotlib.pyplot
from matplotlib.pyplot import imshow

width = 4000
height = 3000
max_dim = 100

full_image = Image.new('RGBA', (width, height))
for img, x, y in zip(images, tx, ty):
    tile = Image.open(img)
    rs = max(1, tile.width/max_dim, tile.height/max_dim)
    tile = tile.resize((int(tile.width/rs), int(tile.height/rs)), Image.ANTIALIAS)
    full_image.paste(tile, (int((width-max_dim)*x), int((height-max_dim)*y)), mask=tile.convert('RGBA'))

matplotlib.pyplot.figure(figsize = (16,12))
imshow(full_image)

# %% [markdown]
# ### Save a json and a png of the cluster

# %%
import os
import json

full_image.save("../test_tSNE.png")

tsne_path = "../test_tSNE.json"

data = [{"path":os.path.abspath(img), "point":[float(x), float(y)]} for img, x, y in zip(images, tx, ty)]
with open(tsne_path, 'w') as outfile:
    json.dump(data, outfile)

print("saved t-SNE result to %s" % tsne_path)
# Out:
# saved t-SNE result to test_tSNE.json

# %% [markdown]
# ### Paste into grid

# %% [raw]
# pip install rasterfairy-py3

# %%
import rasterfairy
nx = 50
ny = 50

grid_assignment = rasterfairy.transformPointCloud2D(tsne)
# Out:
# no good rectangle found for 3184 points, using incomplete square 56 * 57

# %%
tile_width = 50
tile_height = 50

full_width = tile_width * nx
full_height = tile_height * ny
aspect_ratio = float(tile_width) / tile_height

grid_image = Image.new('RGBA', (full_width, full_height))

for img, grid_pos in zip(images, grid_assignment[0]):
    idx_x, idx_y = grid_pos
    x, y = tile_width * idx_x, tile_height * idx_y
    tile = Image.open(img)
    tile_ar = float(tile.width) / tile.height  # center-crop the tile to match aspect_ratio
    if (tile_ar > aspect_ratio):
        margin = 0.5 * (tile.width - aspect_ratio * tile.height)
        tile = tile.crop((margin, 0, margin + aspect_ratio * tile.height, tile.height))
    else:
        margin = 0.5 * (tile.height - float(tile.width) / aspect_ratio)
        tile = tile.crop((0, margin, tile.width, margin + float(tile.width) / aspect_ratio))
    tile = tile.resize((tile_width, tile_height), Image.ANTIALIAS)
    grid_image.paste(tile, (int(x), int(y)))

matplotlib.pyplot.figure(figsize = (16,12))
imshow(grid_image)

# %%
background = Image.new("RGB", grid_image.size, (255, 255, 255))
background.paste(grid_image, mask=grid_image.split()[3]) # 3 is the alpha channel

background.save('../grid-tSNE.jpg', 'JPEG', quality=100)
